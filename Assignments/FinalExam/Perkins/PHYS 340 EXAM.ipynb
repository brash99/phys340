# %% [markdown]
# for f(x) = |x|
#
# where -pi < x < pi

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 1000)
x = abs(x)
y = x

plt.xlabel('x')
plt.ylabel('y')
plt.grid()

n = np.arange(1, 10)

yf = np.zeros(len(x))

for i in range(5):
    yf = yf - 2 / ((i+1) * np.pi) * ( (-1) ** (i+1) ) * np.sin((i+1) * np.pi * x)
    
plt.plot(x, yf, 'r')

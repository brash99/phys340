# %% [markdown]
# # Vector Triple Product
#
# The vector triple product is a vector identity that is useful in simplifying vector expressions. It is given by
#
# \begin{equation}
# \mathbf{A} \times (\mathbf{B} \times \mathbf{C}) = \mathbf{B}(\mathbf{A} \cdot \mathbf{C}) - \mathbf{C}(\mathbf{A} \cdot \mathbf{B})
# \end{equation}
#
# ## Proof
#
# The proof of the vector triple product is given as follows.
#
# Let $\mathbf{A} = a_1\mathbf{i} + a_2\mathbf{j} + a_3\mathbf{k}$, $\mathbf{B} = b_1\mathbf{i} + b_2\mathbf{j} + b_3\mathbf{k}$, and $\mathbf{C} = c_1\mathbf{i} + c_2\mathbf{j} + c_3\mathbf{k}$.
#
# Then, the vector product $\mathbf{B} \times \mathbf{C}$ is given by
#
# \begin{equation}
# \mathbf{B} \times \mathbf{C} = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# b_1 & b_2 & b_3 \\
# c_1 & c_2 & c_3
# \end{vmatrix}
# \end{equation}
#
# \begin{equation}
# = (b_2c_3 - b_3c_2)\mathbf{i} - (b_1c_3 - b_3c_1)\mathbf{j} + (b_1c_2 - b_2c_1)\mathbf{k}
# \end{equation}
#
# Now, the vector product $\mathbf{A} \times (\mathbf{B} \times \mathbf{C})$ is given by
#
# \begin{equation}
# \mathbf{A} \times (\mathbf{B} \times \mathbf{C}) = \begin{vmatrix}
# \mathbf{i} & \mathbf{j} & \mathbf{k} \\
# a_1 & a_2 & a_3 \\
# (b_2c_3 - b_3c_2) & -(b_1c_3 - b_3c_1) & (b_1c_2 - b_2c_1)
# \end{vmatrix}
# \end{equation}
#
# \begin{equation}
# = (a_2(b_1c_2 - b_2c_1) - a_3(b_3c_1 - b_1c_3))\mathbf{i} - \\
# (a_1(b_1c_2 - b_2c_1) - a_3(b_2c_3 - b_3c_2))\mathbf{j} + \\
# (a_1(b_3c_1 - b_1c_3) - a_2(b_2c_3 - b_3c_2))\mathbf{k}
# \end{equation}
#
# Now, the vector product $\mathbf{B}(\mathbf{A} \cdot \mathbf{C})$ is given by
#
# \begin{equation}
# \mathbf{B}(\mathbf{A} \cdot \mathbf{C}) = (b_1\mathbf{i} + b_2\mathbf{j} + b_3\mathbf{k})(a_1c_1 + a_2c_2 + a_3c_3)
# \end{equation}
#
# \begin{equation}
# = (b_1a_1c_1 + b_1a_2c_2 + b_1a_3c_3)\mathbf{i} + \\
# (b_2a_1c_1 + b_2a_2c_2 + b_2a_3c_3)\mathbf{j} + \\
# (b_3a_1c_1 + b_3a_2c_2 + b_3a_3c_3)\mathbf{k}
# \end{equation}
#
# Similarly, the vector product $\mathbf{C}(\mathbf{A} \cdot \mathbf{B})$ is given by
#
# \begin{equation}
# \mathbf{C}(\mathbf{A} \cdot \mathbf{B}) = (c_1\mathbf{i} + c_2\mathbf{j} + c_3\mathbf{k})(a_1b_1 + a_2b_2 + a_3b_3)
# \end{equation}
#
# \begin{equation}
# = (c_1a_1b_1 + c_1a_2b_2 + c_1a_3b_3)\mathbf{i} + \\
# (c_2a_1b_1 + c_2a_2b_2 + c_2a_3b_3)\mathbf{j} + \\
# (c_3a_1b_1 + c_3a_2b_2 + c_3a_3b_3)\mathbf{k}
# \end{equation}
#
# Therefore, evaluating the right hand side of the vector triple product, we get
#
# \begin{equation}
# \mathbf{B}(\mathbf{A} \cdot \mathbf{C}) - \mathbf{C}(\mathbf{A} \cdot \mathbf{B}) = (b_1a_1c_1 + b_1a_2c_2 + b_1a_3c_3)\mathbf{i} + (b_2a_1c_1 + b_2a_2c_2 + b_2a_3c_3)\mathbf{j} + \\
# (b_3a_1c_1 + b_3a_2c_2 + b_3a_3c_3)\mathbf{k} - (c_1a_1b_1 + c_1a_2b_2 + c_1a_3b_3)\mathbf{i} - \\
# (c_2a_1b_1 + c_2a_2b_2 + c_2a_3b_3)\mathbf{j} - (c_3a_1b_1 + c_3a_2b_2 + c_3a_3b_3)\mathbf{k}
# \end{equation}
#
# \begin{equation}
# = (b_1a_1c_1 + b_1a_2c_2 + b_1a_3c_3 - c_1a_1b_1 - c_1a_2b_2 - c_1a_3b_3)\mathbf{i} + \\
# (b_2a_1c_1 + b_2a_2c_2 + b_2a_3c_3 - c_2a_1b_1 - c_2a_2b_2 - c_2a_3b_3)\mathbf{j} + \\
# (b_3a_1c_1 + b_3a_2c_2 + b_3a_3c_3 - c_3a_1b_1 - c_3a_2b_2 - c_3a_3b_3)\mathbf{k}
# \end{equation}
#
# \begin{equation}
# = (b_1a_2c_2 + b_1a_3c_3 - c_1a_2b_2 - c_1a_3b_3)\mathbf{i} + \\
# (b_2a_1c_1 + b_2a_3c_3 - c_2a_1b_1 - c_2a_3b_3)\mathbf{j} + \\
# (b_3a_1c_1 + b_3a_2c_2 - c_3a_1b_1 - c_3a_2b_2)\mathbf{k}
# \end{equation}
#
# Looking at the common factors of the $a$-components in each term, and factoring them out, we get:
#
# \begin{equation}
# \mathbf{B}(\mathbf{A} \cdot \mathbf{C}) - \mathbf{C}(\mathbf{A} \cdot \mathbf{B}) = (a_2(b_1c_2 - b_2c_1) - a_3(b_1c_3 - b_3c_1))\mathbf{i} - \\
# (a_1(b_1c_2 - b_2c_1) - a_3(b_2c_3 - b_3c_2))\mathbf{j} + \\
# (a_1(b_3c_1 - b_1c_3) - a_2(b_2c_3 - b_3c_2))\mathbf{k}
# \end{equation}
#
# Therefore, we have shown that
#
# \begin{equation}
# \mathbf{A} \times (\mathbf{B} \times \mathbf{C}) = \mathbf{B}(\mathbf{A} \cdot \mathbf{C}) - \mathbf{C}(\mathbf{A} \cdot \mathbf{B})
# \end{equation}

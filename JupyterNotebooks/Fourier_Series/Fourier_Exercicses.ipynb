# %% [markdown]
# # Question 1:
#
# Find the Fourier series of the function $f(x) = x^2$ on the interval $[-\pi, \pi]$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Solution:
#
# The Fourier series of a function $f(x)$ on the interval $[-\pi, \pi]$ is given by
#
# $$
# f(x) = \frac{a_0}{2} + \sum_{n=1}^{\infty} \left( a_n \cos(nx) + b_n \sin(nx) \right)
# $$
#
# where
#
# $$
# a_0 = \frac{1}{\pi} \int_{-\pi}^{\pi} f(x) \, dx
# $$
#
# $$
# a_n = \frac{1}{\pi} \int_{-\pi}^{\pi} f(x) \cos(nx) \, dx
# $$
#
# $$
# b_n = \frac{1}{\pi} \int_{-\pi}^{\pi} f(x) \sin(nx) \, dx
# $$
#
# Now, since $f(x) = x^2$ is an even function, we have that $b_n = 0$ for all $n$.
#
# We can calculate $a_0$ and $a_n$ as follows:
#
# $$
# a_0 = \frac{1}{\pi} \int_{-\pi}^{\pi} x^2 \, dx = \frac{1}{\pi} \left[ \frac{x^3}{3} \right]_{-\pi}^{\pi} = \frac{2\pi^2}{3}
# $$
#
# $$
# a_n = \frac{1}{\pi} \int_{-\pi}^{\pi} x^2 \cos(nx) \, dx = \frac{1}{\pi} \frac{2(\pi^2 n^2 -2)\sin(\pi n) + 4 \pi n \cos(\pi n)}{n^3}
# $$
#
# Now, we have that $\sin(\pi n) = 0$ for all $n$, and $\cos(\pi n) = (-1)^n$. Therefore, we have that
#
# $$
# a_n = \frac{4(-1)^n}{n^2}
# $$
#
# So, the Fourier series of $f(x) = x^2$ on the interval $[-\pi, \pi]$ is given by
#
# $$
# f(x) = \frac{\pi^2}{3} + 4 \sum_{n=1}^{\infty} \frac{(-1)^n}{n^2} \cos(nx)
# $$
#
# $$ = \frac{\pi^2}{3} - 4 \cos(x) + \cos(2x) - \frac{4}{9} \cos(3x) + \frac{1}{4} \cos(4x) + \cdots
# $$

# %%
# Plot the Fourier series of f(x) = x^2

x = np.linspace(-3*np.pi, 3*np.pi, 1000)

def f(x):
    return x**2

def fourier_series(x, n):
    s = np.pi**2/3
    for i in range(1, n+1):
        s += 4*(-1)**i/i**2 * np.cos(i*x)
    return s

plt.plot(x, f(x), label='f(x) = x^2')
plt.plot(x, fourier_series(x, 1), label='Fourier series, n=1')
plt.plot(x, fourier_series(x, 5), label='Fourier series, n=5')
plt.plot(x, fourier_series(x, 10), label='Fourier series, n=10')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# Draw axes
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)

plt.title('Fourier series of f(x) = x^2')
plt.show()

# %% [markdown]
# # Question 2:
